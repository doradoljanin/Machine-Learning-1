# %% [markdown]
# Sveučilište u Zagrebu
# Fakultet elektrotehnike i računarstva
#
# ## Strojno učenje 1 2021/2022
# http://www.fer.unizg.hr/predmet/struce1

# %% [markdown]
# ------------------------------
#
# ### Procjena parametara
#
# *Verzija: 1.0
# Zadnji put ažurirano: 1. listopada 2021.*
#
# (c) 2015-2021 Jan Šnajder, Domagoj Alagić
#
# Rok za predaju: **19. prosinca 2021. u 23:59h**
#
# ------------------------------

# %%
import sys
# !{sys.executable} -m pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\dolja\anaconda3\lib\site-packages (0.1.16)
# Requirement already satisfied: scipy in c:\users\dolja\appdata\roaming\python\python38\site-packages (from pgmpy) (1.7.1)
# Requirement already satisfied: torch in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (1.10.1)
# Requirement already satisfied: statsmodels in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (0.12.0)
# Requirement already satisfied: tqdm in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (4.50.2)
# Requirement already satisfied: pyparsing in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (2.4.7)
# Requirement already satisfied: scikit-learn in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (0.23.2)
# Requirement already satisfied: joblib in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (0.17.0)
# Requirement already satisfied: pandas in c:\users\dolja\appdata\roaming\python\python38\site-packages (from pgmpy) (1.3.3)
# Requirement already satisfied: networkx in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (2.5)
# Requirement already satisfied: numpy in c:\users\dolja\anaconda3\lib\site-packages (from pgmpy) (1.19.2)
# Requirement already satisfied: typing-extensions in c:\users\dolja\anaconda3\lib\site-packages (from torch->pgmpy) (3.7.4.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\dolja\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dolja\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dolja\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dolja\appdata\roaming\python\python38\site-packages (from pandas->pgmpy) (2021.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\dolja\appdata\roaming\python\python38\site-packages (from networkx->pgmpy) (5.1.0)
# Requirement already satisfied: six in c:\users\dolja\anaconda3\lib\site-packages (from patsy>=0.5->statsmodels->pgmpy) (1.15.0)

# %% [markdown]
# ### Upute
#
# Ova laboratorijska vježba sastoji se od tri zadatka. U nastavku slijedite upute navedene u ćelijama s tekstom. Rješavanje vježbe svodi se na **dopunjavanje ove bilježnice**: umetanja ćelije ili više njih **ispod** teksta zadatka, pisanja odgovarajućeg kôda te evaluiranja ćelija.
#
# Osigurajte da u potpunosti **razumijete** kôd koji ste napisali. Kod predaje vježbe, morate biti u stanju na zahtjev asistenta (ili demonstratora) preinačiti i ponovno evaluirati Vaš kôd. Nadalje, morate razumjeti teorijske osnove onoga što radite, u okvirima onoga što smo obradili na predavanju. Ispod nekih zadataka možete naći i pitanja koja služe kao smjernice za bolje razumijevanje gradiva (**nemojte pisati** odgovore na pitanja u bilježnicu). Stoga se nemojte ograničiti samo na to da riješite zadatak, nego slobodno eksperimentirajte. To upravo i jest svrha ovih vježbi.
#
# Vježbe trebate raditi **samostalno**. Možete se konzultirati s drugima o načelnom načinu rješavanja, ali u konačnici morate sami odraditi vježbu. U protivnome vježba nema smisla.

# %%
# Učitaj osnovne biblioteke...
import sklearn
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np
import matplotlib.pyplot as plt
import pgmpy as pgm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1. Procjena maksimalne izglednosti

# %% [markdown]
# #### (a)
#
# Definirajte funkciju izglednosti $\mathcal{L}(\mu|\mathcal{D})$ za skup $\mathcal{D}=\{x^{(i)}\}_{i=1}^N$ Bernoullijevih varijabli. Neka od $N$ varijabli njih $m$ ima vrijednost 1 (npr. od $N$ bacanja novčića, $m$ puta smo dobili glavu). Definirajte funkciju izglednosti tako da je parametrizirana s $N$ i $m$, dakle definirajte funkciju $\mathcal{L}(\mu|N,m)$.

# %%
def L(mu, N, m):
    return pow(mu, m) * pow(1 - mu, N - m)

# %% [markdown]
# #### (b)

# %% [markdown]
# Prikažite funkciju $\mathcal{L}(\mu|N,m)$ za (1) $N=10$ i $m=1,2,5,9$ te za (2) $N=100$ i $m=1,10,50,90$ (dva zasebna grafikona).

# %%
mu_values = np.linspace(0,1,100)

N1 = 10
m1 = [1, 2, 5, 9]

N2 = 100
m2 = [1, 10, 50, 90]

for m in m1:
    plt.plot(mu_values, [L(mu, N1, m) for mu in mu_values])
plt.show()
for m in m2:
    plt.plot(mu_values, [L(mu, N2, m) for mu in mu_values])

# %% [markdown]
# **Q:** Koja vrijednost odgovara ML-procjenama i zašto?

# %% [markdown]
# #### (c)
#
# Prikažite funkciju $\mathcal{L}(\mu|N,m)$ za $N=10$ i $m=\{0,9\}$.

# %%
mu_values = np.linspace(0,1,100)
N = 10
m_values = [0, 9]
for m in m_values:
    plt.plot(mu_values, [L(mu, N, m) for mu in mu_values])
plt.show()

# %% [markdown]
# **Q:** Koja je ML-procjena za $\mu$ i što je problem s takvom procjenom u ovome slučaju?

# %% [markdown]
# ### 2. Procjena maksimalne aposteriorne vjerojatnosti

# %% [markdown]
# #### (a)
#
# Prikažite beta-distribuciju $B(\mu|\alpha,\beta)$ za različite kombinacije parametara $\alpha$ i $\beta$, uključivo $\alpha=\beta=1$ te $\alpha=\beta=2$.

# %%
from scipy.stats import beta

mu_values = np.linspace(0,1,100)

plt.plot(mu_values, beta.pdf(mu_values, 0.5, 0.5))
plt.plot(mu_values, beta.pdf(mu_values, 1, 1))
plt.plot(mu_values, beta.pdf(mu_values, 2, 2))
plt.plot(mu_values, beta.pdf(mu_values, 4, 2))
plt.plot(mu_values, beta.pdf(mu_values, 2, 4))

# %% [markdown]
# **Q:** Koje parametere biste odabrali za modeliranje apriornog znanja o parametru $\mu$ za novčić za koji mislite da je "donekle pravedan, ali malo češće pada na glavu"? Koje biste parametre odabrali za novčić za koji držite da je posve pravedan? Zašto uopće koristimo beta-distribuciju, a ne neku drugu?

# %% [markdown]
# #### (b)
#
# Definirajte funkciju za izračun zajedničke vjerojatnosti $P(\mu,\mathcal{D}) = P(\mathcal{D}|\mu) \cdot P(\mu|\alpha,\beta)$ te prikažite tu funkciju za $N=10$ i $m=9$ i nekolicinu kombinacija parametara $\alpha$ i $\beta$.

# %%
def P(mu, N, m, a, b):
    return L(mu, N, m) * beta.pdf(mu, a, b)

# %%
N = 10
m = 9
mu_values = np.linspace(0,1,100)

plt.plot(mu_values, [P(mu, N, m, 0.5, 0.5) for mu in mu_values], color = "g")
plt.plot(mu_values, [P(mu, N, m, 1, 1) for mu in mu_values], color = "r")
plt.plot(mu_values, [P(mu, N, m, 2, 2) for mu in mu_values], color = "b")
plt.plot(mu_values, [P(mu, N, m, 4, 2) for mu in mu_values], color = "y")
plt.plot(mu_values, [P(mu, N, m, 2, 4) for mu in mu_values], color = "g")
# Out:
# C:\Users\dolja\AppData\Local\Temp/ipykernel_11456/1017708123.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return L(mu, N, m) * beta.pdf(mu, a, b)

# %% [markdown]
# **Q**: Koje vrijednosti odgovaraju MAP-procjeni za $\mu$? Usporedite ih sa ML-procjenama.

# %% [markdown]
# #### (c)
#
# Za $N=10$ i $m=1$, na jednome grafikonu prikažite sve tri distribucije: $P(\mu,\mathcal{D})$, $P(\mu|\alpha,\beta)$ i $\mathcal{L}(\mu|\mathcal{D})$.

# %%
N = 10
m = 1
mu_values = np.linspace(0,1,100)

plt.plot(mu_values, [P(mu, N, m, 2, 2) for mu in mu_values], color = "g")
plt.plot(mu_values, beta.pdf(mu_values, 2, 2), color = "r")
plt.plot(mu_values, [L(mu, N, m) for mu in mu_values], color = "b")

# %% [markdown]
# ### 3. Analiza skupa podataka *Iris*

# %% [markdown]
# #### (a)
#
# Učitajte skup podataka *Iris* korištenjem funkcije [`load_iris`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html). Taj skup sadrži $n=4$ značajke i $K=3$ klase. Odaberite jednu klasu i odaberite sve primjere iz te klase, dok ostale primjere zanemarite (**u nastavku radite isključivo s primjerima iz te jedne klase**). Vizualizirajte podatke tako da načinite 2D-prikaze za svaki par značajki (šest grafikona; za prikaz je najjednostavnije koristiti funkciju [`scatter`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)).
#
# **NB:** Mogla bi Vam dobro dući funkcija [`itertools.combinations`](https://docs.python.org/2/library/itertools.html#itertools.combinations).

# %%
from sklearn.datasets import load_iris
import itertools as it

data = load_iris()
X = data['data']
X_class_0 = np.array([X[i] for i, e in enumerate(data['target']) if e == 0]).T
for pair in it.combinations(X_class_0, 2):
    plt.scatter(pair[0], pair[1])
    plt.show()

# %% [markdown]
# #### (b)
#
# Pogledajte opis modula [`stats`](http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html) te proučite funkciju [`norm`](http://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.norm.html#scipy.stats.norm). Implementirajte funkciju log-izglednosti za parametre $\mu$ i $\sigma^2$ normalne distribucije.

# %%
from scipy.stats import norm

def L_gauss(x, mi, sigma):
    return np.log(np.prod(norm.pdf(x, loc=mi, scale=sigma)))

# %% [markdown]
# #### (c)
# Izračunajte ML-procjene za $(\mu, \sigma^2)$ za svaku od $n=4$ značajki iz skupa *Iris*. Ispišite log-izglednosti tih ML-procjena.

# %%
print("ML-procjene za mi, sigma:")
for i in range(4):
    print("\tza x" + str(i) + ":")
    x_i = np.array(X_class_0[i,:])
    
    mi = np.mean(x_i)
    print("\t\tmi = " + str(mi))
    
    sigma = np.std(x_i)
    print("\t\tsigma = " + str(sigma))
    
    print("\t\tLog izglednost parametara norm. distr.:" + str(L_gauss(x_i, mi, sigma)))
# Out:
# ML-procjene za mi, sigma:
# 	za x0:
# 		mi = 5.006
# 		sigma = 0.3489469873777391
# 		Log izglednost parametara norm. distr.:-18.305163312803863
# 	za x1:
# 		mi = 3.428
# 		sigma = 0.37525458025186054
# 		Log izglednost parametara norm. distr.:-21.939396526466602
# 	za x2:
# 		mi = 1.4620000000000002
# 		sigma = 0.17191858538273283
# 		Log izglednost parametara norm. distr.:17.089786091159766
# 	za x3:
# 		mi = 0.24599999999999997
# 		sigma = 0.1043264108459598
# 		Log izglednost parametara norm. distr.:42.0646097912948

# %% [markdown]
# #### (d)
#
# Proučite funkciju [`pearsonr`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html) za izračun Pearsonovog koeficijenta korelacije. Izračunajte koeficijente korelacije između svih četiri značajki u skupu *Iris*.

# %%
from scipy.stats import pearsonr

for pair in it.combinations(X_class_0, 2):
    print(pearsonr(pair[0], pair[1])[0])
# Out:
# 0.7425466856651598
# 0.26717575886875716
# 0.27809835293596963
# 0.17769996678227074
# 0.23275201136287943
# 0.33163004080411873

# %% [markdown]
# #### (e)
#
# Proučite funkciju [`cov`](http://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html) te izračunajte ML-procjenu za kovarijacijsku matricu za skup *Iris*. Usporedite pristranu i nepristranu procjenu. Pokažite da se razlika (srednja apsolutna i kvadratna) smanjuje s brojem primjera (npr. isprobajte za $N/4$ i $N/2$ i $N$ primjera).

# %%
print("\nProcjena kov. matrice: ")
print(np.cov(X_class_0))

print("\nPristrana procjena: ")
print(np.cov(X_class_0, bias=True))

print("\nNepristrana procjena: ")
print(np.cov(X_class_0, bias=False))

abs_diffs = []
square_diffs = []

Ns = [len(X_class_0[0])//4, len(X_class_0[0])//2, len(X_class_0[0])]

for N in Ns:
    print("\nBroj primjera: " + str(N))
    bias_cov = np.cov(X_class_0[:, :N], bias=True)
    unbias_cov = np.cov(X_class_0[:, :N], bias=False)
    print("Srednja apsolutna razlika: " + str(mean(abs(bias_cov - unbias_cov))))
    print("Srednja kvadratna razlika: " + str(mean(pow(bias_cov - unbias_cov, 2))))
    abs_diffs.append(mean(abs(bias_cov - unbias_cov)))
    square_diffs.append(mean(pow(bias_cov - unbias_cov, 2)))
    
for i in range(len(abs_diffs)):
    plt.scatter(Ns[i], abs_diffs[i], color = "g")
plt.show()
for i in range(len(abs_diffs)):
    plt.scatter(Ns[i], square_diffs[i], color = "r")
# Out:
# Procjena kov. matrice:
# [[0.12424898 0.09921633 0.0163551  0.01033061]
#  [0.09921633 0.1436898  0.01169796 0.00929796]
#  [0.0163551  0.01169796 0.03015918 0.00606939]
#  [0.01033061 0.00929796 0.00606939 0.01110612]]
#
# Pristrana procjena:
# [[0.121764 0.097232 0.016028 0.010124]
#  [0.097232 0.140816 0.011464 0.009112]
#  [0.016028 0.011464 0.029556 0.005948]
#  [0.010124 0.009112 0.005948 0.010884]]
#
# Nepristrana procjena:
# [[0.12424898 0.09921633 0.0163551  0.01033061]
#  [0.09921633 0.1436898  0.01169796 0.00929796]
#  [0.0163551  0.01169796 0.03015918 0.00606939]
#  [0.01033061 0.00929796 0.00606939 0.01110612]]
#
# Broj primjera: 12
# Srednja apsolutna razlika: 0.0023989898989899023
# Srednja kvadratna razlika: 1.293849160799922e-05
#
# Broj primjera: 25
# Srednja apsolutna razlika: 0.00184933333333333
# Srednja kvadratna razlika: 7.68007149999998e-06
#
# Broj primjera: 50
# Srednja apsolutna razlika: 0.0007689234693877533
# Srednja kvadratna razlika: 1.451848323615155e-06
